# %% [markdown]
# # Apply Git version control best practices

# %% [markdown]
# ## Understand Git folders in Azure Databricks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/02-01-understand-git-folders.svg)

# %% [markdown]
# ## Clone a repository to start working

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/02-02-clone-repository.svg)

# %% [markdown]
# ## Pull changes from the remote repository

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/02-03-pull-changes.svg)

# %% [markdown]
# ## Keep your repository organized

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/02-04-keep-repo-organized.svg)

# %% [markdown]
# # Manage branching and pull requests

# %% [markdown]
# ## Create and manage branches

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/03-01-create-manage-branches.svg)

# %% [markdown]
# ## Commit and push changes

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/03-02-commit-push-changes.svg)

# %% [markdown]
# ## Work with pull requests

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/03-03-work-with-pull-requests.svg)

# %% [markdown]
# ## Resolve merge conflicts

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/03-04-resolve-merge-conflicts.svg)

# %% [markdown]
# # Implement testing strategy

# %% [markdown]
# ## Understand the testing pyramid

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/04-01-testing-pyramid.svg)

# %% [markdown]
# ## Implement unit tests with pytest

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/04-02-unit-tests-pytest.svg)

# %% [markdown]
# ## Design integration tests

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/04-03-integration-tests.svg)

# %% [markdown]
# ## Create end-to-end tests

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/04-04-end-to-end-tests.svg)

# %% [markdown]
# ## Plan user acceptance testing

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/04-05-user-acceptance-testing.svg)

# %% [markdown]
# ## Organize your test structure

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/04-06-organize-test-structure.svg)

# %% [markdown]
# # Configure and package DABs

# %% [markdown]
# ## Understand the bundle configuration structure

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/05-01-bundle-configuration-structure.svg)

# %% [markdown]
# ## Customize deployment parameters with variables

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/05-02-variables.svg)

# %% [markdown]
# ## Configure resources and task definitions

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/05-03-resources-task-definitions.svg)

# %% [markdown]
# ## Set up deployment targets

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/05-04-deployment-targets.svg)

# %% [markdown]
# # Deploy bundle with Databricks CLI

# %% [markdown]
# ## Validate bundle configuration

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/06-01-validate-bundle.svg)

# %% [markdown]
# ## Preview deployment changes

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/06-02-preview-deployment.svg)

# %% [markdown]
# ## Deploy bundle to a target workspace

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/06-03-deploy-bundle.svg)

# %% [markdown]
# ## Verify deployed resources

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/06-04-verify-resources.svg)

# %% [markdown]
# ## Troubleshoot common deployment issues

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/Demo/mindmaps/learn.wwl.implement-development-lifecycle-processes-azure-databricks/06-05-troubleshoot-deployment.svg)
