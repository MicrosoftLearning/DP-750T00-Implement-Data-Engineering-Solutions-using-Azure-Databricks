# %% [markdown]
# # Apply naming conventions

# %% [markdown]
# ## Understand Unity Catalog naming requirements

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/02-naming-requirements.svg)

# %% [markdown]
# ## Apply naming patterns for data organization

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/02-naming-patterns.svg)

# %% [markdown]
# ## Design naming strategies for environment isolation

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/02-environment-isolation.svg)

# %% [markdown]
# ## Apply naming conventions for compute and development resources

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/02-compute-dev-naming.svg)

# %% [markdown]
# ## Implement conventions across your organization

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/02-implement-conventions.svg)

# %% [markdown]
# # Create catalog

# %% [markdown]
# ## What is a catalog?

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/03-what-is-catalog.svg)

# %% [markdown]
# ## Organize data with catalogs

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/03-organize-with-catalogs.svg)

# %% [markdown]
# ## Create a catalog

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/03-create-catalog.svg)

# %% [markdown]
# ## Configure managed storage

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/03-managed-storage.svg)

# %% [markdown]
# # Create schema

# %% [markdown]
# ## What is a schema?

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/04-what-is-schema.svg)

# %% [markdown]
# ## Organize data with schemas

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/04-organize-with-schemas.svg)

# %% [markdown]
# ## Create a schema

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/04-create-schema.svg)

# %% [markdown]
# ## Configure managed storage

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/04-schema-managed-storage.svg)

# %% [markdown]
# # Create tables and views

# %% [markdown]
# ## Create managed tables

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/05-managed-tables.svg)

# %% [markdown]
# ## Define primary keys and foreign keys

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/05-primary-foreign-keys.svg)

# %% [markdown]
# ## Create external tables

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/05-external-tables.svg)

# %% [markdown]
# ## Create standard views

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/05-standard-views.svg)

# %% [markdown]
# ## Create dynamic views for access control

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/05-dynamic-views.svg)

# %% [markdown]
# ## Create materialized views

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/05-materialized-views.svg)

# %% [markdown]
# ## Best practices for tables and views

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/05-best-practices.svg)

# %% [markdown]
# # Create volumes

# %% [markdown]
# ## What are volumes?

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/06-what-are-volumes.svg)

# %% [markdown]
# ## Choose between managed and external volumes

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/06-managed-vs-external-volumes.svg)

# %% [markdown]
# ## Create a volume

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/06-create-volume.svg)

# %% [markdown]
# ## Access files in volumes

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/06-access-files.svg)

# %% [markdown]
# ## Manage volume permissions

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/06-volume-permissions.svg)

# %% [markdown]
# # Implement DDL operations

# %% [markdown]
# ## Create functions for reusable logic

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/07-functions.svg)

# %% [markdown]
# ## Create procedures for multi-step operations

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/07-procedures.svg)

# %% [markdown]
# ## Modify catalog ownership and properties

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/07-alter-catalog.svg)

# %% [markdown]
# ## Modify table structure and constraints

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/07-alter-table.svg)

# %% [markdown]
# # Implement foreign catalog

# %% [markdown]
# ## Why implement foreign catalogs?

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/08-why-foreign-catalogs.svg)

# %% [markdown]
# ## Understand connections and foreign catalogs

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/08-connections-foreign-catalogs.svg)

# %% [markdown]
# ## Configure a connection to the external database

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/08-configure-connection.svg)

# %% [markdown]
# ## Create a foreign catalog using the connection

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/08-create-foreign-catalog.svg)

# %% [markdown]
# ## Grant access and query foreign data

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/08-grant-query-foreign.svg)

# %% [markdown]
# # Configure AI/BI Genie instructions

# %% [markdown]
# ## Configure the knowledge store

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/09-knowledge-store.svg)

# %% [markdown]
# ## Define data relationships and value sampling

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/09-relationships-sampling.svg)

# %% [markdown]
# ## Add SQL instructions and examples

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/09-sql-instructions.svg)

# %% [markdown]
# ## Apply iterative refinement

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.create-and-organize-objects-in-unity-catalog/09-iterative-refinement.svg)
