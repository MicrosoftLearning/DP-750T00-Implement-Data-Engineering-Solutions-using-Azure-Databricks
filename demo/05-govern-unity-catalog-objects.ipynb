# %% [markdown]
# # Create and preserve table definitions

# %% [markdown]
# ## Add comments to tables and columns

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/02-add-comments-tables-columns.svg)

# %% [markdown]
# ## Apply tags for organization and discovery

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/02-apply-tags-organization-discovery.svg)

# %% [markdown]
# ## Explore and discover database objects

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/02-explore-discover-database-objects.svg)

# %% [markdown]
# # Configure ABAC with tags and policies

# %% [markdown]
# ## Understand governed tags

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/03-understand-governed-tags.svg)

# %% [markdown]
# ## Create row filter policies

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/03-create-row-filter-policies.svg)

# %% [markdown]
# ## Create column mask policies

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/03-create-column-mask-policies.svg)

# %% [markdown]
# ## Follow UDF best practices

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/03-follow-udf-best-practices.svg)

# %% [markdown]
# ## Understand policy inheritance and scope

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/03-understand-policy-inheritance-scope.svg)

# %% [markdown]
# # Apply data retention policies

# %% [markdown]
# ## Configure Delta Lake retention settings

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/04-configure-delta-lake-retention-settings.svg)

# %% [markdown]
# ## Remove obsolete data with VACUUM

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/04-remove-obsolete-data-vacuum.svg)

# %% [markdown]
# ## Handle compliance deletion requests

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/04-handle-compliance-deletion-requests.svg)

# %% [markdown]
# ## Automate retention with predictive optimization

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/04-automate-retention-predictive-optimization.svg)

# %% [markdown]
# ## Integrate with Azure Storage lifecycle policies

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/04-integrate-azure-storage-lifecycle-policies.svg)

# %% [markdown]
# # Set up and manage data lineage

# %% [markdown]
# ## Understand data lineage in Unity Catalog

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/05-understand-data-lineage.svg)

# %% [markdown]
# ## View data lineage using Catalog Explorer

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/05-view-data-lineage-catalog-explorer.svg)

# %% [markdown]
# ## Manage table ownership

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/05-manage-table-ownership.svg)

# %% [markdown]
# ## View table history and version changes

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/05-view-table-history-version-changes.svg)

# %% [markdown]
# ## Query lineage data programmatically

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/05-query-lineage-data-programmatically.svg)

# %% [markdown]
# ## Understand lineage limitations

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/05-understand-lineage-limitations.svg)

# %% [markdown]
# # Configure audit logging

# %% [markdown]
# ## Understand the audit log system table

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/06-understand-audit-log-system-table.svg)

# %% [markdown]
# ## Identify tracked events and services

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/06-identify-tracked-events-services.svg)

# %% [markdown]
# ## Query audit logs for common scenarios

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/06-query-audit-logs-common-scenarios.svg)

# %% [markdown]
# ## Enable verbose audit logs

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/06-enable-verbose-audit-logs.svg)

# %% [markdown]
# ## Configure log delivery to external systems

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/06-configure-log-delivery-external-systems.svg)

# %% [markdown]
# # Design secure Delta Sharing strategy

# %% [markdown]
# ## Choose the right sharing protocol

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/07-choose-sharing-protocol.svg)

# %% [markdown]
# ## Design authentication and access controls

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/07-design-authentication-access-controls.svg)

# %% [markdown]
# ## Configure shares and recipients

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/07-configure-shares-recipients.svg)

# %% [markdown]
# ## Implement fine-grained access with dynamic views

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/07-implement-fine-grained-access-dynamic-views.svg)

# %% [markdown]
# ## Monitor sharing activity through audit logs

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.govern-unity-catalog-objects/07-monitor-sharing-activity-audit-logs.svg)
