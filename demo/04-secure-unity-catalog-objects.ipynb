# %% [markdown]
# # Understand query lifecycle

# %% [markdown]
# ## The query lifecycle in Unity Catalog

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/02-query-lifecycle-unity-catalog.svg)

# %% [markdown]
# ## How queries work with Apache Hive

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/02-query-lifecycle-hive.svg)

# %% [markdown]
# # Implement access control strategies

# %% [markdown]
# ## Querying a table with explicit permissions at each level

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/03-explicit-permissions.svg)

# %% [markdown]
# ## Querying a table with inherited permissions from schema

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/03-inherited-permissions-schema.svg)

# %% [markdown]
# ## Querying a table with inherited permissions from catalog

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/03-inherited-permissions-catalog.svg)

# %% [markdown]
# ## Creating a table: explicit at schema

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/03-create-table-explicit.svg)

# %% [markdown]
# ## Creating a table: inherited from catalog

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/03-create-table-inherited.svg)

# %% [markdown]
# ## Verify granted privileges

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/03-verify-granted-privileges.svg)

# %% [markdown]
# ## Understand Access Control Lists (ACLs)

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/03-understand-acls.svg)

# %% [markdown]
# # Understand fine-grained access control

# %% [markdown]
# ## Why fine-grained control matters

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/04-why-fine-grained-control-matters.svg)

# %% [markdown]
# ## Row and column security

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/04-row-column-security.svg)

# %% [markdown]
# ## Dynamic views

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/04-dynamic-views.svg)

# %% [markdown]
# ## Why row and column security is preferred

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/04-why-row-column-security-preferred.svg)

# %% [markdown]
# ## When dynamic views still make sense

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/04-when-dynamic-views-make-sense.svg)

# %% [markdown]
# ## Comparing row and column security with dynamic views

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/04-comparing-approaches.svg)

# %% [markdown]
# ## Typical workflow

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/04-typical-workflow.svg)

# %% [markdown]
# ## Common pitfalls

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/04-common-pitfalls.svg)

# %% [markdown]
# # Implement row filtering and column masking

# %% [markdown]
# ## Row and column security

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/05-row-column-security.svg)

# %% [markdown]
# ## Dynamic views

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/05-dynamic-views.svg)

# %% [markdown]
# ## Choosing between the two approaches

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/05-choosing-between-approaches.svg)

# %% [markdown]
# # Access Azure Key Vault secrets

# %% [markdown]
# ## Understanding secret scopes in Azure Databricks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/06-understanding-secret-scopes.svg)

# %% [markdown]
# ## Creating an Azure Key Vault-backed secret scope

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/06-creating-secret-scope.svg)

# %% [markdown]
# ## Retrieving secrets in notebooks and jobs

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/06-retrieving-secrets.svg)

# %% [markdown]
# ## Using the secret() function in SQL

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/06-secret-function-sql.svg)

# %% [markdown]
# ## Using secrets in Spark configurations

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/06-spark-configurations.svg)

# %% [markdown]
# ## Reference secrets in environment variables

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/06-environment-variables.svg)

# %% [markdown]
# ## Managing secret scope permissions

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/06-managing-secret-scope-permissions.svg)

# %% [markdown]
# # Authenticate data access with service principals

# %% [markdown]
# ## Understanding service principals for data access

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/07-understanding-service-principals.svg)

# %% [markdown]
# ## Using service principals with Unity Catalog

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/07-service-principals-unity-catalog.svg)

# %% [markdown]
# ## Using service principals in notebooks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/07-service-principals-notebooks.svg)

# %% [markdown]
# ## Security considerations and best practices

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/07-security-considerations.svg)

# %% [markdown]
# # Authenticate resource access with managed identities

# %% [markdown]
# ## Understanding managed identities for Unity Catalog

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/08-understanding-managed-identities.svg)

# %% [markdown]
# ## Creating storage credentials with managed identities

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/08-creating-storage-credentials.svg)

# %% [markdown]
# ## Accessing external storage through storage credentials

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.secure-unity-catalog-objects/08-accessing-external-storage.svg)
