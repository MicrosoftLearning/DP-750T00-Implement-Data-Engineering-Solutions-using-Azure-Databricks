# %% [markdown]
# # Implement validation checks

# %% [markdown]
# ## Understand validation approaches in Azure Databricks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/02-understand-validation-approaches.svg)

# %% [markdown]
# ## Implement nullability checks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/02-implement-nullability-checks.svg)

# %% [markdown]
# ## Validate data cardinality

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/02-validate-data-cardinality.svg)

# %% [markdown]
# ## Apply range checking

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/02-apply-range-checking.svg)

# %% [markdown]
# ## Choose actions for validation failures

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/02-choose-actions-validation-failures.svg)

# %% [markdown]
# # Implement data type checks

# %% [markdown]
# ## Understand schema enforcement

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/03-understand-schema-enforcement.svg)

# %% [markdown]
# ## Use explicit type casting

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/03-use-explicit-type-casting.svg)

# %% [markdown]
# ## Implement type validation with constraints

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/03-implement-type-validation-constraints.svg)

# %% [markdown]
# ## Handle type mismatches in pipelines

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/03-handle-type-mismatches-pipelines.svg)

# %% [markdown]
# ## Use pipeline expectations for type checking

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/03-use-pipeline-expectations-type-checking.svg)

# %% [markdown]
# # Detect and manage schema drift

# %% [markdown]
# ## Recognize schema drift challenges

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/04-recognize-schema-drift-challenges.svg)

# %% [markdown]
# ## Detect and respond to schema drift

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/04-detect-respond-schema-drift.svg)

# %% [markdown]
# ## Implement error handling strategies

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/04-implement-error-handling-strategies.svg)

# %% [markdown]
# ## Apply best practices for schema management

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/04-apply-best-practices-schema-management.svg)

# %% [markdown]
# # Manage data quality with pipeline expectations

# %% [markdown]
# ## Define expectations with three components

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/05-define-expectations-three-components.svg)

# %% [markdown]
# ## Choose the right action for invalid records

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/05-choose-right-action-invalid-records.svg)

# %% [markdown]
# ## Combine multiple expectations for comprehensive checks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/05-combine-multiple-expectations.svg)

# %% [markdown]
# ## Monitor expectation results

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-manage-data-quality-constraints-unity-catalog/05-monitor-expectation-results.svg)
