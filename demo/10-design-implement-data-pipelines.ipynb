# %% [markdown]
# # Design order of operations for a pipeline

# %% [markdown]
# ## Ingest data from source systems

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/02-ingest-data.svg)

# %% [markdown]
# ## Clean and validate data

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/02-clean-validate-data.svg)

# %% [markdown]
# ## Transform data for consumption

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/02-transform-data.svg)

# %% [markdown]
# ## Load data to target destinations

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/02-load-data.svg)

# %% [markdown]
# ## Serve data to consumers

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/02-serve-data.svg)

# %% [markdown]
# ## Monitor and optimize pipeline performance

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/02-monitor-optimize.svg)

# %% [markdown]
# # Choose notebook vs Lakeflow Pipelines

# %% [markdown]
# ## Understand the two approaches

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/03-two-approaches.svg)

# %% [markdown]
# ## When notebooks fit best

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/03-notebooks-fit-best.svg)

# %% [markdown]
# ## When Lakeflow Spark Declarative Pipelines fit best

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/03-lakeflow-fit-best.svg)

# %% [markdown]
# ## Compare the approaches

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/03-compare-approaches.svg)

# %% [markdown]
# ## Make your decision

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/03-make-decision.svg)

# %% [markdown]
# # Design Lakeflow job logic

# %% [markdown]
# ## Understand task relationships in a job

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/04-task-relationships.svg)

# %% [markdown]
# ## Design task execution patterns

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/04-task-execution-patterns.svg)

# %% [markdown]
# ## Add conditional logic to task flows

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/04-conditional-logic.svg)

# %% [markdown]
# ## Implement iterative processing with For each

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/04-iterative-processing.svg)

# %% [markdown]
# ## Configure parameters for flexibility

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/04-parameters.svg)

# %% [markdown]
# ## Select compute resources for tasks

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/04-compute-resources.svg)

# %% [markdown]
# # Design error handling in pipelines and jobs

# %% [markdown]
# ## Understand error handling responsibilities

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/05-error-handling-responsibilities.svg)

# %% [markdown]
# ## Define data quality expectations in declarative pipelines

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/05-data-quality-expectations.svg)

# %% [markdown]
# ## Configure job-level error handling

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/05-job-level-error-handling.svg)

# %% [markdown]
# ## Implement error handling in notebooks

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/05-notebook-error-handling.svg)

# %% [markdown]
# ## Apply error handling best practices

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/05-best-practices.svg)

# %% [markdown]
# # Create pipeline with notebook

# %% [markdown]
# ## Add a notebook task to a Lakeflow Job

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/06-add-notebook-task.svg)

# %% [markdown]
# ## Configure task dependencies

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/06-configure-task-dependencies.svg)

# %% [markdown]
# ## Create a notebook task from scratch

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/06-create-notebook-task.svg)

# %% [markdown]
# ## Pass parameters between notebooks

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/06-pass-parameters.svg)

# %% [markdown]
# ## Best practices for notebook pipelines

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/06-best-practices.svg)

# %% [markdown]
# # Create pipeline with Lakeflow Spark Declarative Pipelines

# %% [markdown]
# ## Understand the declarative approach

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/07-declarative-approach.svg)

# %% [markdown]
# ## Define streaming tables for data ingestion

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/07-streaming-tables.svg)

# %% [markdown]
# ## Create materialized views for transformations

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/07-materialized-views.svg)

# %% [markdown]
# ## Apply data quality expectations

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/07-data-quality-expectations.svg)

# %% [markdown]
# ## Develop pipelines with the Lakeflow Pipelines Editor

# %% [markdown]
# ![](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-pipelines/07-lakeflow-editor.svg)
