# %% [markdown]
# # Get started with Azure Databricks

# %% [markdown]
# ## Navigating the Azure Databricks Workspace UI

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/02-navigating-workspace-ui.svg)

# %% [markdown]
# ## Get help from Databricks Assistant

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/02-databricks-assistant.svg)

# %% [markdown]
# # Identify Azure Databricks workloads

# %% [markdown]
# ## Data Engineering

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/03-data-engineering.svg)

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/03-machine-learning.svg)

# %% [markdown]
# ## SQL

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/03-sql.svg)

# %% [markdown]
# # Understand key concepts

# %% [markdown]
# ## Workspaces

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/04-workspaces.svg)

# %% [markdown]
# ## Notebooks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/04-notebooks.svg)

# %% [markdown]
# ## Clusters

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/04-clusters.svg)

# %% [markdown]
# ## Databricks Runtime

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/04-databricks-runtime.svg)

# %% [markdown]
# ## Lakeflow Jobs

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/04-lakeflow-jobs.svg)

# %% [markdown]
# ## Delta Lake

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/04-delta-lake.svg)

# %% [markdown]
# ## Databricks SQL

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/04-databricks-sql.svg)

# %% [markdown]
# ## SQL Warehouses

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/04-sql-warehouses.svg)

# %% [markdown]
# ## MLflow

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/04-mlflow.svg)

# %% [markdown]
# # Data governance using Unity Catalog and Microsoft Purview

# %% [markdown]
# ## Unity Catalog

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/05-unity-catalog.svg)

# %% [markdown]
# ## Microsoft Purview

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.explore-azure-databricks/05-microsoft-purview.svg)
