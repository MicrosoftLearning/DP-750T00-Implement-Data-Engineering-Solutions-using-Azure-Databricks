# %% [markdown]
# # Design ingestion logic and data source configuration

# %% [markdown]
# ## Understand extraction types

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/02-understand-extraction-types.svg)

# %% [markdown]
# ## Design for change data capture

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/02-design-for-cdc.svg)

# %% [markdown]
# ## Identify source file type characteristics

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/02-source-file-types.svg)

# %% [markdown]
# ## Data source connection considerations

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/02-data-source-connections.svg)

# %% [markdown]
# ## Apply a requirements-driven design framework

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/02-ingestion-design-framework.svg)

# %% [markdown]
# # Choose a data ingestion tool

# %% [markdown]
# ## Understand the ingestion tool landscape

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/03-ingestion-tool-landscape.svg)

# %% [markdown]
# ## Lakeflow Connect

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/03-lakeflow-connect.svg)

# %% [markdown]
# ## Auto Loader

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/03-auto-loader.svg)

# %% [markdown]
# ## COPY INTO

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/03-copy-into.svg)

# %% [markdown]
# ## Spark Structured Streaming

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/03-structured-streaming.svg)

# %% [markdown]
# ## JDBC and ODBC connections

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/03-jdbc-odbc.svg)

# %% [markdown]
# ## Azure Data Factory

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/03-azure-data-factory.svg)

# %% [markdown]
# ## Apply a decision framework

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/03-tool-decision-framework.svg)

# %% [markdown]
# # Choose a data table format

# %% [markdown]
# ## Understand file formats versus table formats

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/04-file-vs-table-formats.svg)

# %% [markdown]
# ## How Parquet stores data differently

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/04-parquet-storage.svg)

# %% [markdown]
# ## Delta Lake as the default format

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/04-delta-lake.svg)

# %% [markdown]
# ## Apache Iceberg for cross-platform scenarios

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/04-apache-iceberg.svg)

# %% [markdown]
# ## When row-based formats apply

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/04-row-based-formats.svg)

# %% [markdown]
# ## Apply decision criteria

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/04-format-decision-criteria.svg)

# %% [markdown]
# # Design and implement a data partitioning scheme

# %% [markdown]
# ## Determine when partitioning applies

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/05-when-partitioning-applies.svg)

# %% [markdown]
# ## Choose effective partition keys

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/05-partition-key-selection.svg)

# %% [markdown]
# ## Implement partitions in Azure Databricks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/05-implement-partitions.svg)

# %% [markdown]
# ## Avoid common partitioning mistakes

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/05-partitioning-mistakes.svg)

# %% [markdown]
# ## Consider liquid clustering as an alternative

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/05-liquid-clustering-alternative.svg)

# %% [markdown]
# # Choose a slowly changing dimension (SCD) type

# %% [markdown]
# ## Understand dimension changes

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/06-dimension-changes.svg)

# %% [markdown]
# ## SCD Type 0

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/06-scd-types-overview.svg)

# %% [markdown]
# ## SCD Type 1

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/06-scd-types-overview.svg)

# %% [markdown]
# ## SCD Type 2

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/06-scd-types-overview.svg)

# %% [markdown]
# ## SCD Type 3

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/06-scd-types-overview.svg)

# %% [markdown]
# ## Compare SCD types

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/06-scd-types-overview.svg)

# %% [markdown]
# ## Apply mixed SCD strategies

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/06-mixed-scd-strategies.svg)

# %% [markdown]
# # Implement a slowly changing dimension (SCD) type 2

# %% [markdown]
# ## Create the SCD Type 2 table

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/07-scd2-table-design.svg)

# %% [markdown]
# ## Implement change capture with MERGE

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/07-merge-scd2.svg)

# %% [markdown]
# ## Query historical data

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/07-query-scd2-history.svg)

# %% [markdown]
# # Design and implement a temporal (history) table to record changes over time

# %% [markdown]
# ## Understand temporal tables versus SCD Type 2

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/08-temporal-vs-scd2.svg)

# %% [markdown]
# ## Enable change data feed for row-level tracking

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/08-change-data-feed.svg)

# %% [markdown]
# ## Query table history

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/08-time-travel.svg)

# %% [markdown]
# ## Use time travel for point-in-time queries

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/08-time-travel.svg)

# %% [markdown]
# ## Persist change history for long-term auditing

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/08-persist-change-history.svg)

# %% [markdown]
# ## Configure retention for compliance requirements

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/08-retention-compliance.svg)

# %% [markdown]
# # Choose granularity on a column or table based on requirements

# %% [markdown]
# ## Understand what granularity represents

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/09-granularity-concept.svg)

# %% [markdown]
# ## Evaluate factors that influence granularity decisions

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/09-granularity-factors.svg)

# %% [markdown]
# ## Apply granularity to fact tables

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/09-fact-table-granularity.svg)

# %% [markdown]
# ## Apply granularity to dimension tables

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/09-dimension-granularity.svg)

# %% [markdown]
# ## Balance trade-offs when selecting granularity

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/09-granularity-tradeoffs.svg)

# %% [markdown]
# # Choose managed vs unmanaged tables

# %% [markdown]
# ## Understand managed tables

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/10-managed-tables.svg)

# %% [markdown]
# ## Understand external tables

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/10-external-tables.svg)

# %% [markdown]
# ## Compare key characteristics

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/10-managed-vs-external-criteria.svg)

# %% [markdown]
# ## Evaluate decision criteria

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/10-managed-vs-external-criteria.svg)

# %% [markdown]
# ## Apply best practices

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/10-managed-vs-external-criteria.svg)

# %% [markdown]
# # Design and implement a clustering strategy

# %% [markdown]
# ## Understand data skipping fundamentals

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/11-data-skipping.svg)

# %% [markdown]
# ## Implement liquid clustering for new tables

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/11-liquid-clustering.svg)

# %% [markdown]
# ## Migrate from Z-ordering to liquid clustering

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/11-zorder-migration.svg)

# %% [markdown]
# ## Manage deletion vectors for efficient updates

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.design-implement-data-modeling-unity-catalog/11-deletion-vectors.svg)
