# %% [markdown]
# # Create job setup and configuration

# %% [markdown]
# ## Understand job structure

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/02-01-job-structure.svg)

# %% [markdown]
# ## Create a job and add tasks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/02-02-create-job-tasks.svg)

# %% [markdown]
# ## Configure task sources

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/02-03-task-sources.svg)

# %% [markdown]
# ## Configure compute resources

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/02-04-compute-resources.svg)

# %% [markdown]
# ## Set up task dependencies

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/02-05-task-dependencies.svg)

# %% [markdown]
# ## Add job parameters

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/02-06-job-parameters.svg)

# %% [markdown]
# ## Organize with tags

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/02-07-tags-permissions.svg)

# %% [markdown]
# ## Configure job access permissions

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/02-07-tags-permissions.svg)

# %% [markdown]
# ## Configure run identity and Unity Catalog access

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/02-08-run-identity.svg)

# %% [markdown]
# # Configure job triggers

# %% [markdown]
# ## Understand trigger types for automated job execution

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/03-01-trigger-types.svg)

# %% [markdown]
# ## Configure table update triggers

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/03-02-table-update-triggers.svg)

# %% [markdown]
# ## Configure file arrival triggers

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/03-03-file-arrival-triggers.svg)

# %% [markdown]
# ## Configure continuous triggers

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/03-04-continuous-triggers.svg)

# %% [markdown]
# ## Manage trigger lifecycle

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/03-05-trigger-lifecycle.svg)

# %% [markdown]
# # Schedule a job

# %% [markdown]
# ## Create a simple schedule

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/04-01-simple-schedule.svg)

# %% [markdown]
# ## Configure an advanced schedule

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/04-02-advanced-schedule.svg)

# %% [markdown]
# ## Choose the right time zone

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/04-03-time-zone.svg)

# %% [markdown]
# ## Control concurrent job runs

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/04-04-concurrent-runs.svg)

# %% [markdown]
# # Configure job alerts

# %% [markdown]
# ## Understand notification events

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/05-01-notification-events.svg)

# %% [markdown]
# ## Configure notification destinations

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/05-02-notification-destinations.svg)

# %% [markdown]
# ## Add notifications to a job

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/05-03-add-notifications.svg)

# %% [markdown]
# ## Configure task-level notifications

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/05-03-add-notifications.svg)

# %% [markdown]
# ## Reduce notification noise

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/05-04-reduce-noise.svg)

# %% [markdown]
# ## Monitor with HTTP webhooks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/05-05-webhooks-adf.svg)

# %% [markdown]
# ## Monitor pipelines in Azure Data Factory

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/05-05-webhooks-adf.svg)

# %% [markdown]
# # Configure automatic restarts

# %% [markdown]
# ## Understand retry behavior in Lakeflow Jobs

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/06-01-retry-behavior.svg)

# %% [markdown]
# ## Configure task-level retry policies

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/06-02-task-retry-policies.svg)

# %% [markdown]
# ## Configure continuous jobs for always-on workloads

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/06-03-continuous-jobs.svg)

# %% [markdown]
# ## Set timeout thresholds to prevent hung tasks

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/06-04-timeout-thresholds.svg)

# %% [markdown]
# ## Combine automatic restarts with notifications

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/06-05-restarts-notifications.svg)

# %% [markdown]
# ## Apply best practices for production workloads

# %% [markdown]
# ![diagram](https://raw.githubusercontent.com/MicrosoftLearning/DP-750T00-Implement-Data-Engineering-Solutions-using-Azure-Databricks/refs/heads/main/demo/mindmaps/learn.wwl.implement-lakeflow-jobs/06-06-best-practices.svg)
